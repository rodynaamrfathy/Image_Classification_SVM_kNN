# %% [markdown]
# # Step 2: Data augmentation
# Implement in src/augment.py later
#
# ### Apply techniques like:
# - Rotation
# - Horizontal/Vertical flipping
# - Scaling / Cropping
# - Color jitter / brightness adjustment
# ### Target: Increase dataset by at least 30%, especially for minority classes.
# - Save augmented images or implement augmentation on-the-fly during training.

# %% [markdown]
# > after exploring data in the prev notebook and removing courpted images and counting no. of images for each class we found that
# ### Images per class:
# - cardboard: 259 images
# - glass: 401 images
# - metal: 328 images
# - paper: 476 images
# - plastic: 386 images
# - trash: 110 images

# %% [markdown]
# # Apply Data Augmentation Using ImageDataGenerator (Keras)
# > documentation : https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
# > video: https://www.youtube.com/watch?v=Ahy50JCRYNk

# %% [markdown]
# - `ImageDataGenerator`: Class used to apply data augmentation to images.
# - `img_to_array`: Converts a PIL image to a NumPy array (needed for processing).
# - `load_img`: Loads an image from disk as a PIL image.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import os

# %% [markdown]
# > “Every time you load an image, randomly rotate it, shift it, zoom it, or flip it.”
# | Parameter                    | Meaning                                     |
# | ---------------------------- | ------------------------------------------- |
# | `rotation_range=20`          | Rotate image randomly between -20° to +20°  |
# | `width_shift_range=0.1`      | Move image left/right up to 10% of width    |
# | `height_shift_range=0.1`     | Move image up/down up to 10% of height      |
# | `zoom_range=0.1`             | Randomly zoom in/out up to ±10%             |
# | `horizontal_flip=True`       | Flip image horizontally (mirror)            |
# | `brightness_range=[0.8,1.2]` | Randomly change brightness from 80% to 120% |

# %%
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)

# %% [markdown]
# # 2. Function to augment a single class folder

# %%
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png')

def augment_class(input_dir, output_dir, augment_count=5):
    os.makedirs(output_dir, exist_ok=True)

    for image_name in os.listdir(input_dir):
        if not image_name.lower().endswith(IMAGE_EXTENSIONS):
            print(f"⏭ Skipping non-image file: {image_name}")
            continue

        img_path = os.path.join(input_dir, image_name)
        try:
            img = load_img(img_path)
        except:
            print("skipping corrupted file:", img_path)
            continue

        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        prefix = image_name.split('.')[0]
        i = 0
        for batch in datagen.flow(
            x,
            batch_size=1,
            save_to_dir=output_dir,
            save_prefix=prefix,
            save_format='jpg'
        ):
            i += 1
            if i >= augment_count:
                break

# %% [markdown]
# # 3. Function to augment the entire dataset

# %%
def augment_dataset(root="/Users/rodynaamr/Image_Classification_SVM_kNN/data", augment_count=10):
    # List all items in root
    classes = os.listdir(root)

    for cls in classes:
        # Skip hidden files and folders (like .DS_Store)
        if cls.startswith('.'):
            continue
        # Skip already augmented folders
        if cls.endswith('_aug'):
            continue

        input_dir = os.path.join(root, cls)
        output_dir = os.path.join(root, cls + "_aug")
        print(f"Augmenting class {cls}...")
        augment_class(input_dir, output_dir, augment_count=augment_count)

# %% [markdown]
# # 4. Run augmentation

# %%
augment_dataset(root="/Users/rodynaamr/Image_Classification_SVM_kNN/data", augment_count=10)
# Out:
# Augmenting class paper...
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/paper/e9ddd8f5-85d6-45e0-b607-104259ca6fbb.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/paper/3b5bb1a4-7819-4167-a610-5e35c6f4b074.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/paper
jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/trash/a31e2570-f309-4e40-95bc-57ee2dfdf412.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/trash/93380387-da03-44af-9e4b-32c0beece110.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/trash/0e375c5f-34a7-481d-8c55-e5fdaa75f836.jpg
# Augmenting class glass...
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/855b7163-5270-4b11-9271-492ce3c1c048.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/2a3677eb-7c7a-4dea-9157-23c55252d855.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/393f6b9f-f426-4858-9766-7ba12ed51df3.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/002616ff-7ff0-4e6a-9cf9-24f736e56be2.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/14bbfb58-f21f-41ae-9b48-d7d10b41d10e.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/105e6779-0299-4b77-9526-747847b6762f.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/df3b36b0-1e25-4901-a449-a4a3a2c59582.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/b9304563-57f2-4f71-9f19-d845969f7fbb.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/72792053-5f1a-457c-a0da-e5200aadbe1d.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/8fd9489f-3052-4bc6-8cf1-79c3b9286a2e.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/3ea2871a-feb6-4384-8487-c8aff5339d85.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/90cd02d9-1c1a-4cf4-a08f-100f62bf7968.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/369c8be6-5811-427c-a9e9-7acd9101c48d.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/14f50b32-f879-4c07-ba05-54bf3c6a8693.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/e7fd346b-295d-4218-b975-7f25f1c56e24.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/glass/b9ab8ae2-90ee-4cda-8423-3b564669d283.jpg
# Augmenting class plastic...
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/381aeb1b-4efb-4314-8ca8-16c3a981a1f3.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/475dbb63-d767-4f9c-874a-7b133e2aa099.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/dec17c1e-57a9-4746-8ee2-2a9314664654.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/9cc966b8-287a-4922-bcd6-b43721ae1db5.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/73155f34-0d5e-4c69-9396-b4cc76e32863.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/7c35a035-5207-4406-8cf2-0b4ce836d08c.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/097fdf93-03ad-4d62-98a7-02f6b39e87da.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/99733095-4545-46f7-b223-ee30c3c3bb99.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/8a2c0933-7195-4e23-9e56-8382db86461c.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/1d4df275-6e8e-4b8d-8779-6813c6ea7948.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/1db23e25-cbdf-4b5d-925a-9b4f5d600d04.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/09b5dda8-5e1d-4a28-9368-0e72ee0739cb.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/24ba3745-acad-44d4-be6e-9012d421c098.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/1c3fe472-7dce-4b3d-be3a-eeb998fe951e.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/7cc4bc86-2e00-495e-be08-86d998ac5077.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/e5147630-f309-452f-90e7-aeb43878102e.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/d075e307-97d4-4811-a8b0-f90c07ebebbb.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/ce89dde5-22ae-4a76-8cea-875f87dd3e56.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/baa91f90-1fb6-4dd6-a274-69e20e658b0e.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/fd28a009-65e2-4d2b-bc94-6d054ef36734.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/b7584c85-26bf-4a4c-a2f5-1c353154cce5.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/d3c94e8a-f195-473d-b541-9ffa0501a6e7.jpg
# skipping corrupted file: /Users/rodynaamr/Image_Classification_SVM_kNN/data/plastic/e6484c54-fba1-4ced-9789-9dbd9e5cfab6.jpg

# %%
import os
for waste in ["cardboard", "glass", "metal", "paper", "plastic", "trash"]:
    count = 0
    for suffix in ["", "_aug"]:
        folder = f"/Users/rodynaamr/Image_Classification_SVM_kNN/data/{waste}{suffix}"
        if os.path.exists(folder):
            count += len([f for f in os.listdir(folder) if f.endswith(('.png', '.jpg', '.jpeg'))])
    print(f"{waste}: {count}")
# Out:
# cardboard: 2729
# glass: 4249
# metal: 3477
# paper: 4965
# plastic: 4014
# trash: 1169
