# %% [markdown]
# ## **Step 6: Evaluate models**
#
# * Open **`05_evaluation.ipynb`**.
# * Metrics:
#
#   * Accuracy for **6 primary classes** (must ≥ 0.85)
#   * Confusion matrix
#   * Precision/Recall per class
# * Compare **SVM vs k-NN**:
#
#   * Training speed
#   * Inference speed
#   * Memory usage
#   * Accuracy
#
# ---
#
# ## **Step 7: Real-time deployment**
#
# * Open **`main_app.py`**:
#
#   * Use OpenCV to read **camera frames**.
#   * Extract features using `src/features.py`.
#   * Predict with best-performing model.
#   * Display result on screen in real-time.
#
# **Goal:** The application should process frames smoothly and classify material correctly.
#
# ---
#
# ## **Step 8: Documentation & Report**
#
# * Explain:
#
#   1. Feature extraction choices.
#   2. Classifier design decisions.
#   3. Evaluation results and trade-offs.
# * Include screenshots and confusion matrices.
# * Mention how you handled the 'Unknown' class.
#
# ---
#
# ## **Step 9: Submission**
#
# * Zip your **repository** with:
#
#   * `src/`, `notebooks/`, `models/`, `main_app.py`, `requirements.txt`
# * Follow the naming convention for your team.
#
# ---
#
# ✅ **Key Tips:**
#
# * Start small: get **one class + SVM** working first.
# * Then add **k-NN**, then handle all 7 classes.
# * Use **notebooks** for experimentation and scripts for final deployment.
# * Keep track of **augmented images & features** to save time.
# * **Version everything**: dataset splits, features, model weights.
